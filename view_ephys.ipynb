# %%
import matplotlib.pyplot as plt
from fish.ephys.ephys import load, windowed_variance, estimate_swims

# %%
ephys_file = "E:\\jing\\ephys\\20200905\\barcoding-testver3.0.0.10chFlt"
ep = load(ephys_file)
# Out:
# Data needed to be truncated!

# %%
fig, ax = plt.subplots(ep.shape[0], 1, figsize=(ep.shape[0]*2, 10), sharex=True)
for i, channel in enumerate(ep):
    ax[i].plot(channel)

fig.tight_layout()
